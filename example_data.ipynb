# %%
from preprocessing import BloodCellDataset

# %%
ds = BloodCellDataset()

# %%
images, annotations = ds.load_all()

# %%
fig = ds.plot_images(images, n=5, randomize=False)
fig

# %%
bnd_box_img = ds.apply_bounding_boxes(images, annotations)

# %%
ds.plot_images(bnd_box_img, n=5, randomize=False)

# %%
# now downsample to half the image size
res_images, res_ann = ds.apply_downscale(images, annotations, factor=0.5)

# %%
# draw the bounding boxes again to check they are 
# still valid after resizing
res_bnd_box_img = ds.apply_bounding_boxes(res_images, res_ann)

# %%
ds.plot_images(res_bnd_box_img, n=5, randomize=False)
